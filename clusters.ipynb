# %% [raw]
# This is some stuff we will need for the notebook, dont pay it too much mind

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
def scatter1(x1,x2,y1,y2):
    ax=plt.subplot(111)
    plt.plot(x1,y1,'ro')
    plt.plot(x2,y2,'ro')
    plt.show()
def scatter2(x3,x4,y3,y4):
    ax=plt.subplot(111)
    plt.plot(x3,y3,'ro')
    plt.plot(x4,y4,'ro')
    plt.show()
def scatter3(x1,x2,y1,y2):
    ax=plt.subplot(111)
    plt.plot(x1,y1,'ko')
    plt.plot(x2,y2,'ko')
    plt.plot(2.,2.2,'rv')
    plt.plot(1.4,.8,'bv')
    plt.show()
def scatter4(x1,x2,y1,y2):
    ax=plt.subplot(111)
    plt.plot(x1,y1,'ro')
    plt.plot(x2,y2,'bo')
    plt.plot(2.,2.2,'rv')
    plt.plot(1.4,.8,'bv')
    plt.show()
def scatter5(x1,x2,y1,y2):
    ax=plt.subplot(111)
    plt.plot(x1,y1,'ro')
    plt.plot(x2,y2,'bo')
    plt.plot(np.mean(x1),np.mean(y1),'rv')
    plt.plot(np.mean(x2),np.mean(y2),'bv')
    plt.show()

# %%
x1=np.random.normal(3,.3,20)
y1=np.random.normal(3,.3,20)
x2=np.random.normal(0,.4,20)
y2=np.random.normal(0,.4,20)
x3=np.random.normal(3,.2,20)
y3=np.random.normal(3,.2,20)
x4=np.random.normal(2.7,.3,20)
y4=np.random.normal(2.7,.3,20)

# %% [raw]
# That's all for the functions and variables, the lesson is below

# %% [markdown]
# # Quick Note on Unsupervised Learning

# %% [raw]
# Data have "no labels", there may not be a "right answer"
#
# As a result, we are not "training" the algorithm and do not ask it to make predictions
#
# Instead we ask the algorithm to find structure for us
#
# Let us see it in action -> Finding clusters is a form of unsupervised learning

# %% [markdown]
# # Finding Clusters In Our Data

# %% [raw]
# What are clusters?
#
# They are places in parameter space where our data seem to live. Some data may live in certain places while other data may live in other places.
#
# Lets make some fake data to play with to illustrate this point a bit more.
#
# Suppose I hand you a random data set. You dont know much about it, and you decide to plot it

# %%
scatter1(x1,x2,y1,y2)

# %% [raw]
# In the above example, you can might see there two clusters-one seems to live in the upper right corner and one in the lower left. They are well seperated, and the points in a cluster seem to "bunch up" together. Of course, it is not always this simple in practice. We can just as easily find ourselves looking at a data set like this

# %%
scatter2(x3,x4,y3,y4)

# %% [raw]
# How many clusters do you see now? How would you choose which points belong in which cluster? Are clusters well defined in this case, and is it appropriate to use a clustering algorithm?
#
# Lets drive this a little further and try to use this exercise on real life data

# %% [markdown]
# <img src="files/hrddiagrambasicstars.gif">

# %% [raw]
# Supposing you dont know any better about white dwarves, main sequence stars, giants and so forth, you can easily see that some of the data live in different spots, as labeled above. Only, its not alwasys so easy in this plot to distinguish some of these groups from each other (where exactly is the main sequence turn off, for example). Furter more, does the main sequence really count as a cluster? What counts as a cluster anyway, and how do we deal with points that look like they can go either way?
#
# The answer to most of the questions we've asked will come form the kind of clustering algorithm we choose

# %% [markdown]
# ## K-Means Algorithm

# %% [markdown]
# We first provide the number, K, of clussters in our data set we will look for
# randomly initialize the centers of our 'cluster centroids'
# <ol>
# <li>for every point, calculate its distance from all the centroids and remember the smallest one
#     this point now belongs to the cluster associated with this centroid</li>
#     <li>move the centroids to the average position of the points in their cluster</li>
#     <li>repeat until convergence</li>
# </ol>
#
# we are effectively reducing this special function, which we call the cost function
#
# $$\sum_{k=1}^{K} \sum_{i \epsilon C_{k}} (x_{i} - \mu_{k})^{2}$$

# %%
scatter3(x1,x2,y1,y2)

# %%
scatter4(x1,x2,y1,y2)

# %%
scatter5(x1,x2,y1,y2)

# %% [raw]
# Sometimes, we may get unlucky in the initial positions of the centeroids, and wind up with an unenlightening result. This is because the cost function may have local minima and global minima, and our alogrithm can get stuck in local minima. you should run k means several times and choose the result with lowest cost to get around this. Even so, you are *not* guarenteed to have reached the global minima.
#
# As a last note, scikit has a nice routine which does this for you

# %%
#example from the reading
from sklearn.cluster import KMeans

X = np.random.normal(size=(1000,2)) #our toy data
clf = KMeans(n_clusters=3)
clf.fit(X)
centers=clf.cluster_centers_ #locations of clusters
labels=clf.predict(X) #labels for each point

# %% [markdown]
# Lets try to visualize the results with a quick plot

# %%
ax=plt.subplot(111)
ax.scatter(X.T[0], X.T[1],c=labels)
print centers
plt.show()
# Out:
# [[ 0.86204561 -0.56839815]
#  [-0.94611357 -0.43499047]
#  [ 0.09312265  1.04832626]]

# %%
A= np.random.normal(size=(500,2))+5
B= np.random.normal(size=(500,2))
C= np.vstack((A,B))
clf2 = KMeans(n_clusters=3)
clf2.fit(C)
centers2=clf2.cluster_centers_ #locations of clusters
labels2=clf2.predict(C)

# %%
ax=plt.subplot(111)
ax.scatter(C.T[0], C.T[1],c=labels2)
print centers2
plt.show()
# Out:
# [[ -2.13314379e-06  -2.46634131e-02]
#  [  4.31270261e+00   5.39535500e+00]
#  [  5.70281279e+00   4.53795268e+00]]

# %% [raw]
# Now that we have some intuition for how K means works, lets look at the example in the textbook

# %%
# Author: Jake VanderPlas
# License: BSD
#   The figure produced by this code is published in the textbook
#   "Statistics, Data Mining, and Machine Learning in Astronomy" (2013)
#   For more information, see http://astroML.github.com
#   To report a bug or issue, use the following forum:
#    https://groups.google.com/forum/#!forum/astroml-general
import numpy as np
from matplotlib import pyplot as plt
from matplotlib.patches import Ellipse
from scipy.stats import norm

from sklearn.cluster import KMeans
from sklearn import preprocessing

from astroML.datasets import fetch_sdss_sspp

#----------------------------------------------------------------------
# This function adjusts matplotlib settings for a uniform feel in the textbook.
# Note that with usetex=True, fonts are rendered with LaTeX.  This may
# result in an error if LaTeX is not installed on your system.  In that case,
# you can set usetex to False.
from astroML.plotting import setup_text_plots
setup_text_plots(fontsize=8, usetex=False)

#------------------------------------------------------------
# Get data
data = fetch_sdss_sspp(cleaned=True)
X = np.vstack([data['FeH'], data['alphFe']]).T

# truncate dataset for speed
X = X[::5]

#------------------------------------------------------------
# Compute a 2D histogram  of the input
H, FeH_bins, alphFe_bins = np.histogram2d(data['FeH'], data['alphFe'], 50)

#------------------------------------------------------------
# Compute the KMeans clustering
n_clusters = 4

scaler = preprocessing.Scaler()
clf = KMeans(n_clusters)
clf.fit(scaler.fit_transform(X))

#------------------------------------------------------------
# Visualize the results
fig = plt.figure(figsize=(5, 5))
ax = fig.add_subplot()

# plot density
ax = plt.axes()
ax.imshow(H.T, origin='lower', interpolation='nearest', aspect='auto',
          extent=[FeH_bins[0], FeH_bins[-1],
                  alphFe_bins[0], alphFe_bins[-1]],
          cmap=plt.cm.binary)

# plot cluster centers
cluster_centers = scaler.inverse_transform(clf.cluster_centers_)
ax.scatter(cluster_centers[:, 0], cluster_centers[:, 1],
           s=40, c='w', edgecolors='k')

# plot cluster boundaries
FeH_centers = 0.5 * (FeH_bins[1:] + FeH_bins[:-1])
alphFe_centers = 0.5 * (alphFe_bins[1:] + alphFe_bins[:-1])

Xgrid = np.meshgrid(FeH_centers, alphFe_centers)
Xgrid = np.array(Xgrid).reshape((2, 50 * 50)).T

H = clf.predict(scaler.transform(Xgrid)).reshape((50, 50))

for i in range(n_clusters):
    Hcp = H.copy()
    flag = (Hcp == i)
    Hcp[flag] = 1
    Hcp[~flag] = 0

    ax.contour(FeH_centers, alphFe_centers, Hcp, [-0.5, 0.5],
               linewidths=1, colors='k')

ax.xaxis.set_major_locator(plt.MultipleLocator(0.3))
ax.set_xlim(-1.101, 0.101)
ax.set_ylim(alphFe_bins[0], alphFe_bins[-1])

ax.set_xlabel(r'$\rm [Fe/H]$')
ax.set_ylabel(r'$\rm [\alpha/Fe]$')

plt.show()
# Out:
# /Users/ih64/anaconda/lib/python2.7/site-packages/sklearn/preprocessing/data.py:393: DeprecationWarning: Scaler was renamed to StandardScaler. The old name  will be removed in 0.15.
#   " will be removed in 0.15.", DeprecationWarning)

# %% [markdown]
# In these examples, we made up some toy data. In the first case, we happen to know that all the data is drawn from the same distribution (a luxury you are likely not afforded when typically searching for clusters), and we really dont expect to see 3 seperate clusters. And yet, if we ask K means to look for 3 clusters, it will. This raises the question, how many clusters should you search for? How do you choose K? To get around this problem, lets look at another algorithm

# %% [markdown]
# ## Mean Shift Algorithm

# %% [raw]
# We do not have to choose K, the algorithm chooses it for us
#
# we search for over densities in the data, and are sensitive to local extrema
#
# we make a kernel density estimate of the data
#
# we 'move' each point in the direction of the log of the gradient of the density untill they converge

# %%
from sklearn.cluster import MeanShift

ms = MeanShift(bandwidth=1)
X = np.random.normal(size=(1000,2)) #our toy data
ms.fit(X)
centersMS = ms.cluster_centers_
labelsMS = ms.labels_

# %%
ax=plt.subplot(111)
ax.scatter(X.T[0], X.T[1],c=labelsMS)
print centersMS
plt.show()
# Out:
# [[-0.07204118  0.00997804]
#  [ 1.06758215  3.72635602]]

# %%
ms.fit(C)
centersMS2 = ms.cluster_centers_
labelsMS2 = ms.labels_

# %%
ax=plt.subplot(111)
ax.scatter(C.T[0], C.T[1],c=labelsMS2)
print centersMS2
plt.show()
# Out:
# [[ 5.05685456  4.98476037]
#  [-0.04603854  0.02844956]]

# %% [raw]
# The Mean Shift algorithm figured out by itself the number of clusters there were in the data, and grouped the data points accordingly. It is considered to be more accurate than the K means algorithm, but you probabaly noticed it is a little more computationally expensive. This is because the algorithm has to learn the parameters of the density kernel (recall the bandwidth from last week), and preform slightly more complex calculations when taking the log of the gradient of this density
#
# Let's sink our teeth into some more complex data, and review the example in the texbook

# %%
# Author: Jake VanderPlas
# License: BSD
#   The figure produced by this code is published in the textbook
#   "Statistics, Data Mining, and Machine Learning in Astronomy" (2013)
#   For more information, see http://astroML.github.com
#   To report a bug or issue, use the following forum:
#    https://groups.google.com/forum/#!forum/astroml-general
import numpy as np
from matplotlib import pyplot as plt
from matplotlib.patches import Ellipse
from scipy.stats import norm

from sklearn.cluster import MeanShift, estimate_bandwidth
from sklearn import preprocessing

from astroML.datasets import fetch_sdss_sspp

#----------------------------------------------------------------------
# This function adjusts matplotlib settings for a uniform feel in the textbook.
# Note that with usetex=True, fonts are rendered with LaTeX.  This may
# result in an error if LaTeX is not installed on your system.  In that case,
# you can set usetex to False.
from astroML.plotting import setup_text_plots
setup_text_plots(fontsize=8, usetex=False)

#------------------------------------------------------------
# Get the data
np.random.seed(0)
data = fetch_sdss_sspp(cleaned=True)

# cut out some additional strange outliers
data = data[~((data['alphFe'] > 0.4) & (data['FeH'] > -0.3))]

X = np.vstack([data['FeH'], data['alphFe']]).T

#----------------------------------------------------------------------
# Compute clustering with MeanShift
#
# We'll work with the scaled data, because MeanShift finds circular clusters

X_scaled = preprocessing.scale(X)

# The following bandwidth can be automatically detected using
# the routine estimate_bandwidth().  Because bandwidth estimation
# is very expensive in memory and computation, we'll skip it here.

#bandwidth = estimate_bandwidth(X)
bandwidth = 0.4

ms = MeanShift(bandwidth=bandwidth, bin_seeding=True, cluster_all=False)
ms.fit(X_scaled)

labels_unique = np.unique(ms.labels_)
n_clusters = len(labels_unique[labels_unique >= 0])
print labels_unique
print bandwidth
print "number of estimated clusters : %d" % n_clusters

#------------------------------------------------------------

# Plot the results
ax = plt.subplot(111)

# plot density
H, FeH_bins, alphFe_bins = np.histogram2d(data['FeH'], data['alphFe'], 51)

ax.imshow(H.T, origin='lower', interpolation='nearest', aspect='auto',
          extent=[FeH_bins[0], FeH_bins[-1],
                  alphFe_bins[0], alphFe_bins[-1]],
          cmap=plt.cm.binary)

# plot clusters
colors = ['b', 'g', 'r', 'k']

for i in range(n_clusters):
    Xi = X[ms.labels_ == i]
    H, b1, b2 = np.histogram2d(Xi[:, 0], Xi[:, 1], (FeH_bins, alphFe_bins))

    bins = [0.1]

    ax.contour(0.5 * (FeH_bins[1:] + FeH_bins[:-1]),
               0.5 * (alphFe_bins[1:] + alphFe_bins[:-1]),
               H.T, bins, colors='w')

ax.xaxis.set_major_locator(plt.MultipleLocator(0.3))
ax.set_xlim(-1.101, 0.101)
ax.set_ylim(alphFe_bins[0], alphFe_bins[-1])
ax.set_xlabel(r'$\rm [Fe/H]$')
ax.set_ylabel(r'$\rm [\alpha/Fe]$')
plt.show()
# Out:
# [-1  0  1]
# 0.4
# number of estimated clusters : 2

# %% [markdown]
# ##
